# %% [markdown]
# <a href="https://colab.research.google.com/github/alank101/Apple-Pie/blob/main/Load_Data_into_dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""Movie Recommender with Machine Learning.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/106Gtd93VDK9_4Xsrn43Wz0xjL47bQpMa

https://colab.research.google.com/

Data Download Link: https://files.grouplens.org/datasets/movielens/ml-latest-small.zip

Data Source: https://grouplens.org/datasets/movielens/latest/
"""

'''
@article{10.1145/2827872,
author = {Harper, F. Maxwell and Konstan, Joseph A.},
title = {The MovieLens Datasets: History and Context},
year = {2015},
issue_date = {January 2016},
publisher = {Association for Computing Machinery},
address = {New York, NY, USA},
volume = {5},
number = {4},
issn = {2160-6455},
url = {https://doi.org/10.1145/2827872},
doi = {10.1145/2827872},
journal = {ACM Trans. Interact. Intell. Syst.},
month = dec,
articleno = {19},
numpages = {19},
keywords = {Datasets, recommendations, ratings, MovieLens}
}
'''

import pandas

movies_dataframe = pandas.read_csv("movies.csv")

movies_dataframe

movies_dataframe.set_index("movieId", inplace = True)

movies_dataframe

ratings_dataframe = pandas.read_csv("ratings.csv")

ratings_dataframe
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
import pandas

movies_dataframe = pandas.read_csv("movies.csv")
movies_dataframe
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
movies_dataframe.set_index("movieId", inplace = True)

movies_dataframe
# Out:
#                                              title  \
# movieId
# 1                                 Toy Story (1995)
# 2                                   Jumanji (1995)
# 3                          Grumpier Old Men (1995)
# 4                         Waiting to Exhale (1995)
# 5               Father of the Bride Part II (1995)
# ...                                            ...
# 193581   Black Butler: Book of the Atlantic (2017)
# 193583                No Game No Life: Zero (2017)
# 193585                                Flint (2017)
# 193587         Bungo Stray Dogs: Dead Apple (2018)
# 193609         Andrew Dice Clay: Dice Rules (1991)
#
#                                               genres
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy
# ...                                              ...
# 193581               Action|Animation|Comedy|Fantasy
# 193583                      Animation|Comedy|Fantasy
# 193585                                         Drama
# 193587                              Action|Animation
# 193609                                        Comedy
#
# [9742 rows x 2 columns]

# %%
ratings_dataframe = pandas.read_csv("ratings.csv")
ratings_dataframe
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
total_counts = ratings_dataframe["movieId"].value_counts()
total_counts
# Out:
# movieId
# 356       329
# 318       317
# 296       307
# 593       279
# 2571      278
#          ...
# 86279       1
# 86922       1
# 5962        1
# 87660       1
# 163981      1
# Name: count, Length: 9724, dtype: int64

# %%
movies_dataframe["ratingsCount"] = total_counts

movies_dataframe
# Out:
#                                              title  \
# movieId
# 1                                 Toy Story (1995)
# 2                                   Jumanji (1995)
# 3                          Grumpier Old Men (1995)
# 4                         Waiting to Exhale (1995)
# 5               Father of the Bride Part II (1995)
# ...                                            ...
# 193581   Black Butler: Book of the Atlantic (2017)
# 193583                No Game No Life: Zero (2017)
# 193585                                Flint (2017)
# 193587         Bungo Stray Dogs: Dead Apple (2018)
# 193609         Andrew Dice Clay: Dice Rules (1991)
#
#                                               genres  ratingsCount
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy         215.0
# 2                         Adventure|Children|Fantasy         110.0
# 3                                     Comedy|Romance          52.0
# 4                               Comedy|Drama|Romance           7.0
# 5                                             Comedy          49.0
# ...                                              ...           ...
# 193581               Action|Animation|Comedy|Fantasy           1.0
# 193583                      Animation|Comedy|Fantasy           1.0
# 193585                                         Drama           1.0
# 193587                              Action|Animation           1.0
# 193609                                        Comedy           1.0
#
# [9742 rows x 3 columns]

# %%
movies_dataframe.sort_values("ratingsCount", ascending = False).head(10)
# Out:
#                                              title  \
# movieId
# 356                            Forrest Gump (1994)
# 318               Shawshank Redemption, The (1994)
# 296                            Pulp Fiction (1994)
# 593               Silence of the Lambs, The (1991)
# 2571                            Matrix, The (1999)
# 260      Star Wars: Episode IV - A New Hope (1977)
# 480                           Jurassic Park (1993)
# 110                              Braveheart (1995)
# 589              Terminator 2: Judgment Day (1991)
# 527                        Schindler's List (1993)
#
#                                    genres  ratingsCount
# movieId
# 356              Comedy|Drama|Romance|War         329.0
# 318                           Crime|Drama         317.0
# 296           Comedy|Crime|Drama|Thriller         307.0
# 593                 Crime|Horror|Thriller         279.0
# 2571               Action|Sci-Fi|Thriller         278.0
# 260               Action|Adventure|Sci-Fi         251.0
# 480      Action|Adventure|Sci-Fi|Thriller         238.0
# 110                      Action|Drama|War         237.0
# 589                         Action|Sci-Fi         224.0
# 527                             Drama|War         220.0

# %%
average_ratings = ratings_dataframe.groupby("movieId").mean()["rating"]

average_ratings
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: rating, Length: 9724, dtype: float64

# %%
movies_dataframe["averageRating"] = average_ratings

movies_dataframe
# Out:
#                                              title  \
# movieId
# 1                                 Toy Story (1995)
# 2                                   Jumanji (1995)
# 3                          Grumpier Old Men (1995)
# 4                         Waiting to Exhale (1995)
# 5               Father of the Bride Part II (1995)
# ...                                            ...
# 193581   Black Butler: Book of the Atlantic (2017)
# 193583                No Game No Life: Zero (2017)
# 193585                                Flint (2017)
# 193587         Bungo Stray Dogs: Dead Apple (2018)
# 193609         Andrew Dice Clay: Dice Rules (1991)
#
#                                               genres  ratingsCount  \
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy         215.0
# 2                         Adventure|Children|Fantasy         110.0
# 3                                     Comedy|Romance          52.0
# 4                               Comedy|Drama|Romance           7.0
# 5                                             Comedy          49.0
# ...                                              ...           ...
# 193581               Action|Animation|Comedy|Fantasy           1.0
# 193583                      Animation|Comedy|Fantasy           1.0
# 193585                                         Drama           1.0
# 193587                              Action|Animation           1.0
# 193609                                        Comedy           1.0
#
#          averageRating
# movieId
# 1             3.920930
# 2             3.431818
# 3             3.259615
# 4             2.357143
# 5             3.071429
# ...                ...
# 193581        4.000000
# 193583        3.500000
# 193585        3.500000
# 193587        3.500000
# 193609        4.000000
#
# [9742 rows x 4 columns]

# %%
movies_dataframe.sort_values(["ratingsCount", "averageRating"],
                             ascending = False).head(10)
# Out:
#                                              title  \
# movieId
# 356                            Forrest Gump (1994)
# 318               Shawshank Redemption, The (1994)
# 296                            Pulp Fiction (1994)
# 593               Silence of the Lambs, The (1991)
# 2571                            Matrix, The (1999)
# 260      Star Wars: Episode IV - A New Hope (1977)
# 480                           Jurassic Park (1993)
# 110                              Braveheart (1995)
# 589              Terminator 2: Judgment Day (1991)
# 527                        Schindler's List (1993)
#
#                                    genres  ratingsCount  averageRating
# movieId
# 356              Comedy|Drama|Romance|War         329.0       4.164134
# 318                           Crime|Drama         317.0       4.429022
# 296           Comedy|Crime|Drama|Thriller         307.0       4.197068
# 593                 Crime|Horror|Thriller         279.0       4.161290
# 2571               Action|Sci-Fi|Thriller         278.0       4.192446
# 260               Action|Adventure|Sci-Fi         251.0       4.231076
# 480      Action|Adventure|Sci-Fi|Thriller         238.0       3.750000
# 110                      Action|Drama|War         237.0       4.031646
# 589                         Action|Sci-Fi         224.0       3.970982
# 527                             Drama|War         220.0       4.225000

# %%
MINIMUM_RATINGS_COUNT = 100

minimum_ratings_subset = movies_dataframe.query(f"ratingsCount >= {MINIMUM_RATINGS_COUNT}").sort_values("ratingsCount")

minimum_ratings_subset
# Out:
#                                                      title  \
# movieId
# 912                                      Casablanca (1942)
# 4022                                      Cast Away (2000)
# 1517     Austin Powers: International Man of Mystery (1...
# 44191                                V for Vendetta (2006)
# 454                                       Firm, The (1993)
# ...                                                    ...
# 2571                                    Matrix, The (1999)
# 593                       Silence of the Lambs, The (1991)
# 296                                    Pulp Fiction (1994)
# 318                       Shawshank Redemption, The (1994)
# 356                                    Forrest Gump (1994)
#
#                               genres  ratingsCount  averageRating
# movieId
# 912                    Drama|Romance         100.0       4.240000
# 4022                           Drama         100.0       3.700000
# 1517         Action|Adventure|Comedy         100.0       3.535000
# 44191    Action|Sci-Fi|Thriller|IMAX         100.0       3.885000
# 454                   Drama|Thriller         101.0       3.534653
# ...                              ...           ...            ...
# 2571          Action|Sci-Fi|Thriller         278.0       4.192446
# 593            Crime|Horror|Thriller         279.0       4.161290
# 296      Comedy|Crime|Drama|Thriller         307.0       4.197068
# 318                      Crime|Drama         317.0       4.429022
# 356         Comedy|Drama|Romance|War         329.0       4.164134
#
# [138 rows x 4 columns]

# %%
import numpy

USER_1_POSITION_X = 3
USER_1_POSITION_Y = 7.5

USER_2_POSITION_X = 7
USER_2_POSITION_Y = 8

position_user_1 = numpy.array([USER_1_POSITION_X, USER_1_POSITION_Y])

position_user_2 = numpy.array([USER_2_POSITION_X, USER_2_POSITION_Y])

position_user_1
position_user_2
# Out:
# array([7, 8])

# %%
def find_distance_between_users(position_user_1, position_user_2):
  (delta_x, delta_y) = position_user_1 - position_user_2
  return (delta_x ** 2 + delta_y ** 2) ** (1/2)

find_distance_between_users(position_user_1, position_user_2)
# Out:
# 4.031128874149275

# %%
def find_user_ratings(userId):
  user_ratings = ratings_dataframe.query(f"userId == {userId}")

  return user_ratings[["movieId", "rating"]].set_index("movieId")

ID_OF_USER_1 = 1
ID_OF_USER_2 = 610

user_1_ratings = find_user_ratings(ID_OF_USER_1)
user_1_ratings
# Out:
#          rating
# movieId
# 1           4.0
# 3           4.0
# 6           4.0
# 47          5.0
# 50          5.0
# ...         ...
# 3744        4.0
# 3793        5.0
# 3809        4.0
# 4006        4.0
# 5060        5.0
#
# [232 rows x 1 columns]

# %%
user_2_ratings = find_user_ratings(ID_OF_USER_2)
user_2_ratings
# Out:
#          rating
# movieId
# 1           5.0
# 6           5.0
# 16          4.5
# 32          4.5
# 47          5.0
# ...         ...
# 166534      4.0
# 168248      5.0
# 168250      5.0
# 168252      5.0
# 170875      3.0
#
# [1302 rows x 1 columns]

# %%
ratings_comparison = user_1_ratings.join(user_2_ratings, lsuffix="_user1", rsuffix="_user2").dropna()

ratings_comparison
# Out:
#          rating_user1  rating_user2
# movieId
# 1                 4.0           5.0
# 6                 4.0           5.0
# 47                5.0           5.0
# 50                5.0           4.0
# 70                3.0           4.0
# ...               ...           ...
# 3671              5.0           5.0
# 3703              5.0           4.5
# 3740              4.0           4.5
# 3744              4.0           3.0
# 3793              5.0           3.5
#
# [69 rows x 2 columns]

# %%
user1_compared = ratings_comparison["rating_user1"]
user2_compared = ratings_comparison["rating_user2"]

numpy.linalg.norm(user1_compared - user2_compared)
# Out:
# 8.031189202104505

# %%
def find_distance_between_real_users(userId_1, userId_2):
  ratings_user1 = find_user_ratings(userId_1)
  ratings_user2 = find_user_ratings(userId_2)

  if ratings_user1.empty or ratings_user2.empty:
    return "Unable to compare users. Check to see if userId exists"

  ratings_comparison = ratings_user1.join(ratings_user2, lsuffix="_user1", rsuffix="_user2").dropna()
  user1_compared = ratings_comparison["rating_user1"]
  user2_compared = ratings_comparison["rating_user2"]

  distance_between_users = numpy.linalg.norm(user1_compared - user2_compared)


  return [userId_1, userId_2, distance_between_users]

find_distance_between_real_users(1,900)
# Out:
# 'Unable to compare users. Check to see if userId exists'

# %%
def find_relative_distance(userId):
  users = ratings_dataframe["userId"].unique()
  users = users[users != userId]
  distances = [find_distance_between_real_users(userId, every_id) for every_id in users]

  return pandas.DataFrame(distances, columns = ["id", "userId", "distance"])

example_distances = find_relative_distance(7)

example_distances
# Out:
#      id  userId   distance
# 0     7       1   7.106335
# 1     7       2   4.031129
# 2     7       3   0.000000
# 3     7       4   5.634714
# 4     7       5   3.354102
# ..   ..     ...        ...
# 604   7     606  12.579746
# 605   7     607   5.244044
# 606   7     608  14.924812
# 607   7     609   3.122499
# 608   7     610  13.257074
#
# [609 rows x 3 columns]

# %%
def find_top_similar_users(userId):
  distances_to_user = find_relative_distance(userId)
  distances_to_user = distances_to_user.sort_values("distance")
  distances_to_user = distances_to_user.set_index("userId")
  return distances_to_user

SAMPLE_USER_ID = 9

find_top_similar_users(SAMPLE_USER_ID).head(20)
# Out:
#         id  distance
# userId
# 470      9       0.0
# 329      9       0.0
# 150      9       0.0
# 151      9       0.0
# 444      9       0.0
# 258      9       0.0
# 154      9       0.0
# 155      9       0.0
# 442      9       0.0
# 441      9       0.0
# 158      9       0.0
# 159      9       0.0
# 440      9       0.0
# 161      9       0.0
# 162      9       0.0
# 163      9       0.0
# 164      9       0.0
# 436      9       0.0
# 433      9       0.0
# 431      9       0.0

# %%
find_top_similar_users(610).head(20)
# Out:
#          id  distance
# userId
# 406     610  0.000000
# 175     610  0.000000
# 147     610  0.000000
# 429     610  0.500000
# 508     610  0.500000
# 53      610  0.500000
# 545     610  0.500000
# 575     610  1.000000
# 360     610  1.000000
# 158     610  1.118034
# 92      610  1.322876
# 289     610  1.500000
# 35      610  1.500000
# 388     610  1.581139
# 499     610  1.581139
# 595     610  1.581139
# 206     610  1.732051
# 547     610  1.732051
# 451     610  1.870829
# 535     610  1.936492

# %%
def make_movie_recommendations(userId):
  user_ratings = find_user_ratings(userId)
  top_similar_users = find_top_similar_users(userId)
  MOST_SIMILAR = 0
  most_similar_user = top_similar_users.iloc[MOST_SIMILAR]
  most_similar_user_ratings = find_user_ratings(most_similar_user.name)
  unwatched_movies = most_similar_user_ratings.drop(user_ratings.index, errors = "ignore")
  unwatched_movies = unwatched_movies.sort_values("rating", ascending = False)
  recommended_movies = unwatched_movies.join(movies_dataframe)
  return recommended_movies

make_movie_recommendations(SAMPLE_USER_ID)
# Out:
#          rating                                              title  \
# movieId
# 292         5.0                                    Outbreak (1995)
# 589         5.0                  Terminator 2: Judgment Day (1991)
# 587         5.0                                       Ghost (1990)
# 527         5.0                            Schindler's List (1993)
# 356         5.0                                Forrest Gump (1994)
# ...         ...                                                ...
# 420         3.0                       Beverly Hills Cop III (1994)
# 434         3.0                                 Cliffhanger (1993)
# 454         3.0                                   Firm, The (1993)
# 253         3.0  Interview with the Vampire: The Vampire Chroni...
# 231         3.0             Dumb & Dumber (Dumb and Dumber) (1994)
#
#                                         genres  ratingsCount  averageRating
# movieId
# 292               Action|Drama|Sci-Fi|Thriller         101.0       3.425743
# 589                              Action|Sci-Fi         224.0       3.970982
# 587      Comedy|Drama|Fantasy|Romance|Thriller         115.0       3.434783
# 527                                  Drama|War         220.0       4.225000
# 356                   Comedy|Drama|Romance|War         329.0       4.164134
# ...                                        ...           ...            ...
# 420               Action|Comedy|Crime|Thriller          59.0       2.720339
# 434                  Action|Adventure|Thriller         101.0       3.034653
# 454                             Drama|Thriller         101.0       3.534653
# 253                               Drama|Horror         109.0       3.458716
# 231                           Adventure|Comedy         133.0       3.060150
#
# [79 rows x 5 columns]

# %%
NUMBER_OF_NEIGHBORS = 5

def find_k_nearest_neighbors(userId, k=NUMBER_OF_NEIGHBORS):
  distances_to_user = find_relative_distance(userId)
  distances_to_user = distances_to_user.sort_values("distance")
  distances_to_user = distances_to_user.set_index("userId")
  return distances_to_user.head(k)

find_k_nearest_neighbors(SAMPLE_USER_ID, NUMBER_OF_NEIGHBORS)
# Out:
#         id  distance
# userId
# 470      9       0.0
# 329      9       0.0
# 150      9       0.0
# 151      9       0.0
# 444      9       0.0

# %%
def make_recommendation_with_knn(userId):
  top_k_neighbors = find_k_nearest_neighbors(userId)
  ratings_by_index = ratings_dataframe.set_index("userId")
  top_similar_ratings = ratings_by_index.loc[top_k_neighbors.index]
  top_similar_rating_average = top_similar_ratings.groupby("movieId").mean()[["rating"]]
  recommended_movies = top_similar_rating_average.sort_values("rating", ascending = False)
  return recommended_movies.join(movies_dataframe)

make_recommendation_with_knn(SAMPLE_USER_ID)
# Out:
#          rating                                   title  \
# movieId
# 136850      5.0                          Villain (1971)
# 802         5.0                       Phenomenon (1996)
# 111         5.0                      Taxi Driver (1976)
# 235         5.0                          Ed Wood (1994)
# 292         5.0                         Outbreak (1995)
# ...         ...                                     ...
# 1732        0.5                Big Lebowski, The (1998)
# 1080        0.5     Monty Python's Life of Brian (1979)
# 4262        0.5                         Scarface (1983)
# 1206        0.5              Clockwork Orange, A (1971)
# 1136        0.5  Monty Python and the Holy Grail (1975)
#
#                                genres  ratingsCount  averageRating
# movieId
# 136850           Crime|Drama|Thriller           1.0       5.000000
# 802                     Drama|Romance          46.0       3.336957
# 111              Crime|Drama|Thriller         104.0       4.105769
# 235                      Comedy|Drama          70.0       3.678571
# 292      Action|Drama|Sci-Fi|Thriller         101.0       3.425743
# ...                               ...           ...            ...
# 1732                     Comedy|Crime         106.0       3.924528
# 1080                           Comedy          89.0       3.926966
# 4262               Action|Crime|Drama          67.0       3.932836
# 1206      Crime|Drama|Sci-Fi|Thriller         120.0       3.995833
# 1136         Adventure|Comedy|Fantasy         136.0       4.161765
#
# [171 rows x 5 columns]

# %%
NUMBER_OF_MOVIES = 14

ROWS_INDEX = 0

MINIMUM_NUMBER, MAXIMUM_NUMBER = 1, movies_dataframe.shape[ROWS_INDEX]

import random

test_user_watched_movies = []

for i in range(NUMBER_OF_MOVIES):
  random_movie_index = random.randint(MINIMUM_NUMBER, MAXIMUM_NUMBER)
  test_user_watched_movies.append(random_movie_index)

test_user_watched_movies
# Out:
# [5654,
#  9606,
#  2130,
#  3837,
#  79,
#  5715,
#  3573,
#  3041,
#  794,
#  1957,
#  1624,
#  5237,
#  3823,
#  6663]

# %%
MINIMUM_RATING = 0
MAXIMUM_RATING = 5

test_user_ratings = []

for index in range(0, NUMBER_OF_MOVIES):
  random_rating = random.randint(MINIMUM_RATING, MAXIMUM_RATING)
  test_user_ratings.append(random_rating)

test_user_ratings
# Out:
# [0, 1, 4, 1, 0, 5, 1, 3, 1, 3, 2, 4, 2, 3]

# %%
user_data = [list(index) for index in zip(test_user_watched_movies, test_user_ratings)]
user_data

def create_new_user(user_data):
  new_user_id = ratings_dataframe["userId"].max() + 1
  new_user_dataframe = pandas.DataFrame(user_data, columns = ["movieId", "rating"])
  new_user_dataframe["userId"] = new_user_id

  return pandas.concat([ratings_dataframe, new_user_dataframe])

create_new_user(user_data)
# Out:
#     userId  movieId  rating    timestamp
# 0        1        1     4.0  964982703.0
# 1        1        3     4.0  964981247.0
# 2        1        6     4.0  964982224.0
# 3        1       47     5.0  964983815.0
# 4        1       50     5.0  964982931.0
# ..     ...      ...     ...          ...
# 9      611     1957     3.0          NaN
# 10     611     1624     2.0          NaN
# 11     611     5237     4.0          NaN
# 12     611     3823     2.0          NaN
# 13     611     6663     3.0          NaN
#
# [100850 rows x 4 columns]

# %%
NEW_USER_ID = 611

make_recommendation_with_knn(NEW_USER_ID)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-238b27c37db9> in <cell line: 3>()
#       1 NEW_USER_ID = 611
#       2
# ----> 3 make_recommendation_with_knn(NEW_USER_ID)
#
# <ipython-input-103-c3a809645be2> in make_recommendation_with_knn(userId)
#       1 def make_recommendation_with_knn(userId):
# ----> 2   top_k_neighbors = find_k_nearest_neighbors(userId)
#       3   ratings_by_index = ratings_dataframe.set_index("userId")
#       4   top_similar_ratings = ratings_by_index.loc[top_k_neighbors.index]
#       5   top_similar_rating_average = top_similar_ratings.groupby("movieId").mean()[["rating"]]
#
# <ipython-input-102-65ab45d67b38> in find_k_nearest_neighbors(userId, k)
#       2
#       3 def find_k_nearest_neighbors(userId, k=NUMBER_OF_NEIGHBORS):
# ----> 4   distances_to_user = find_relative_distance(userId)
#       5   distances_to_user = distances_to_user.sort_values("distance")
#       6   distances_to_user = distances_to_user.set_index("userId")
#
# <ipython-input-98-f2f4cb42cfc7> in find_relative_distance(userId)
#       4   distances = [find_distance_between_real_users(userId, every_id) for every_id in users]
#       5
# ----> 6   return pandas.DataFrame(distances, columns = ["id", "userId", "distance"])
#       7
#       8 example_distances = find_relative_distance(7)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     820                     )
#     821                 else:
# --> 822                     mgr = ndarray_to_mgr(
#     823                         data,
#     824                         index,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     334     )
#     335
# --> 336     _check_values_indices_shape_match(values, index, columns)
#     337
#     338     if typ == "array":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _check_values_indices_shape_match(values, index, columns)
#     418         passed = values.shape
#     419         implied = (len(index), len(columns))
# --> 420         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     421
#     422
#
# ValueError: Shape of passed values is (610, 1), indices imply (610, 3)
